# %% [markdown]
# <a href="https://colab.research.google.com/github/nafisetofigi/MUSIQ/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# !wget http://datasets.vqa.mmsp-kn.de/archives/koniq10k_1024x768.zip
# Out:
# --2021-12-06 05:29:57--  http://datasets.vqa.mmsp-kn.de/archives/koniq10k_1024x768.zip
# Resolving datasets.vqa.mmsp-kn.de (datasets.vqa.mmsp-kn.de)... 134.34.224.175
# Connecting to datasets.vqa.mmsp-kn.de (datasets.vqa.mmsp-kn.de)|134.34.224.175|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://datasets.vqa.mmsp-kn.de/archives/koniq10k_1024x768.zip [following]
# --2021-12-06 05:29:57--  https://datasets.vqa.mmsp-kn.de/archives/koniq10k_1024x768.zip
# Connecting to datasets.vqa.mmsp-kn.de (datasets.vqa.mmsp-kn.de)|134.34.224.175|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5608799013 (5.2G) [application/zip]
# Saving to: ‘koniq10k_1024x768.zip’
#
# koniq10k_1024x768.z 100%[===================>]   5.22G  26.3MB/s    in 3m 24s
#
# 2021-12-06 05:33:22 (26.2 MB/s) - ‘koniq10k_1024x768.zip’ saved [5608799013/5608799013]

# %%
# !unzip data.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: 1024x768/5785719824.jpg
#  extracting: 1024x768/5786083032.jpg
#  extracting: 1024x768/5786468844.jpg
#  extracting: 1024x768/5786557550.jpg
#  extracting: 1024x768/5788614098.jpg
#  extracting: 1024x768/5788815207.jpg
#  extracting: 1024x768/5789601551.jpg
#  extracting: 1024x768/5790219836.jpg
#  extracting: 1024x768/5791107273.jpg
#  extracting: 1024x768/5791949308.jpg
#  extracting: 1024x768/5793101915.jpg
#  extracting: 1024x768/5794649659.jpg
#  extracting: 1024x768/5794758875.jpg
#  extracting: 1024x768/5795183898.jpg
#  extracting: 1024x768/5796436033.jpg
#  extracting: 1024x768/5796747370.jpg
#  extracting: 1024x768/5796923587.jpg
#  extracting: 1024x768/5797735856.jpg
#  extracting: 1024x768/5798200461.jpg
#  extracting: 1024x768/5798775388.jpg
#  extracting: 1024x768/5799422140.jpg
#  extracting: 1024x768/5802112389.jpg
#  extracting: 1024x768/5802569891.jpg
#  extracting: 1024x768/5803562101.jpg
# ...

# %%
! git clone https://github.com/anse3832/MUSIQ.git
# Out:
# Cloning into 'MUSIQ'...
# remote: Enumerating objects: 103, done.
# remote: Counting objects: 100% (103/103), done.
# remote: Compressing objects: 100% (96/96), done.
# remote: Total 103 (delta 50), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (103/103), 145.58 KiB | 2.35 MiB/s, done.
# Resolving deltas: 100% (50/50), done.

# %%
# !python MUSIQ/option/config.py

# %%
# !python MUSIQ/model/backbone.py

# %%
# !pip3 install einops

# %%
# !wget https://download.pytorch.org/models/resnet50-0676ba61.pth
# Out:
# --2021-12-06 05:36:03--  https://download.pytorch.org/models/resnet50-0676ba61.pth
# Resolving download.pytorch.org (download.pytorch.org)... 52.85.79.23, 52.85.79.49, 52.85.79.74, ...
# Connecting to download.pytorch.org (download.pytorch.org)|52.85.79.23|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 102530333 (98M) [application/x-www-form-urlencoded]
# Saving to: ‘resnet50-0676ba61.pth’
#
# resnet50-0676ba61.p 100%[===================>]  97.78M  59.3MB/s    in 1.6s
#
# 2021-12-06 05:36:05 (59.3 MB/s) - ‘resnet50-0676ba61.pth’ saved [102530333/102530333]

# %%
# !python MUSIQ/train.py
# Out:
# Using GPU 0
# number of train scenes: 8058
# number of test scenes: 2015
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#   0% 14/4029 [00:27<2:11:08,  1.96s/it]
# Traceback (most recent call last):
#   File "MUSIQ/train.py", line 130, in <module>
#     loss, rho_s, rho_p = train_epoch(config, epoch, model_transformer, model_backbone, criterion, optimizer, scheduler, train_loader)
#   File "/content/MUSIQ/trainer.py", line 50, in train_epoch
#     loss.backward()
#   File "/usr/local/lib/python3.7/dist-packages/torch/_tensor.py", line 307, in backward
# ...
